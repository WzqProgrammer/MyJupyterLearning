# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torchvision import datasets, models, transforms
import os
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset
from torch.autograd import Variable
import time

# %%
data_dir = 'F:\DataSets/EmotionImages/TargetData'

data_transform = {x: transforms.Compose([transforms.Resize([256, 256]),  # 设置尺寸
                                        transforms.ToTensor(),  # 转为Tensor
                                        transforms.Normalize([0.485, 0.456, 0.406],
                                                             [0.229, 0.224, 0.225])])  # 标准化
                  for x in {"train", "valid"}}  # {"train":"训练集数据格式","valid":"测试集数据格式"}

image_datasets = {x: datasets.ImageFolder(root=os.path.join(data_dir, x),  # 载入数据
                                         transform = data_transform[x])
                  for x in {"train", "valid"}}  # {"train":"训练集","valid":"测试集"}

dataloader = {x: torch.utils.data.DataLoader(dataset=image_datasets[x],
                                            batch_size=16,
                                            shuffle=True)
              for x in {"train", "valid"}}  # {包装16个为一个批次"train":"训练集数据载入","valid":"测试集数据载入"}

# %%
X_example, y_example = next(iter(dataloader["train"]))  # 迭代得到一个批次的样本
example_classes = image_datasets["train"].classes
index_classes = image_datasets["train"].class_to_idx

# %%
train_data = dataloader["train"]
valid_data = dataloader["valid"]

train_data_size = len(image_datasets["train"])
valid_data_size = len(image_datasets["valid"])

print(train_data_size)
print(valid_data_size)
# Out:
# 1848
# 231

# %%
model = models.resnet101(pretrained=True)  # 使用VGG16 网络预训练好的模型
# Out:
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to C:\Users\WZQAdmin/.cache\torch\checkpoints\resnet101-5d3b4d8f.pth
# 100%|███████████████████████████████████████████████████████████████████████████████| 170M/170M [00:20<00:00, 8.89MB/s]

# %%
resnet50 = model

# %%
for param in resnet50.parameters():
    param.requires_grad = False

# %%
fc_inputs = resnet50.fc.in_features
resnet50.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 3),
    nn.LogSoftmax(dim=1)
)

# %%
loss_func = nn.NLLLoss()
optimizer = optim.Adam(resnet50.parameters())

# %%
def train_and_valid(model, loss_function, optimizer, epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    history = []
    best_acc = 0.0
    best_epoch = 0
 
    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
 
        model.train()
 
        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
 
        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)
 
            #因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()
 
            outputs = model(inputs)
 
            loss = loss_function(outputs, labels)
 
            loss.backward()
 
            optimizer.step()
 
            train_loss += loss.item() * inputs.size(0)
 
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
 
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
            train_acc += acc.item() * inputs.size(0)
 
        with torch.no_grad():
            model.eval()
 
            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)
 
                outputs = model(inputs)
 
                loss = loss_function(outputs, labels)
 
                valid_loss += loss.item() * inputs.size(0)
 
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))
 
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
                valid_acc += acc.item() * inputs.size(0)
 
        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size
 
        avg_valid_loss = valid_loss/valid_data_size
        avg_valid_acc = valid_acc/valid_data_size
 
        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
 
        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1
 
        epoch_end = time.time()
 
        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_valid_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))
 
        torch.save(model, 'F:\DataSets/modles/'+'resnet50_'+str(epoch+1)+'.pt')
    return model, history

# %%
num_epochs = 30
trained_model, history = train_and_valid(resnet50, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/30
# Epoch: 001, Training: Loss: 0.4972, Accuracy: 75.1082%,
# 		Validation: Loss: 0.4972, Accuracy: 78.3550%, Time: 1073.4800s
# Best Accuracy for validation : 0.7835 at epoch 001
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ResNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Bottleneck. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AdaptiveAvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LogSoftmax. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 2/30
# Epoch: 002, Training: Loss: 0.4868, Accuracy: 79.1667%,
# 		Validation: Loss: 0.4868, Accuracy: 81.3853%, Time: 1104.6920s
# Best Accuracy for validation : 0.8139 at epoch 002
# Epoch: 3/30
# Epoch: 003, Training: Loss: 0.5202, Accuracy: 79.8160%,
# 		Validation: Loss: 0.5202, Accuracy: 74.0260%, Time: 1114.0470s
# Best Accuracy for validation : 0.8139 at epoch 002
# Epoch: 4/30
# Epoch: 004, Training: Loss: 0.4491, Accuracy: 80.3571%,
# 		Validation: Loss: 0.4491, Accuracy: 82.2511%, Time: 1111.6700s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 5/30
# Epoch: 005, Training: Loss: 0.4679, Accuracy: 81.4394%,
# 		Validation: Loss: 0.4679, Accuracy: 81.8182%, Time: 1115.2900s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 6/30
# Epoch: 006, Training: Loss: 0.5289, Accuracy: 82.9545%,
# 		Validation: Loss: 0.5289, Accuracy: 75.7576%, Time: 1117.3460s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 7/30
# Epoch: 007, Training: Loss: 0.4612, Accuracy: 81.9264%,
# 		Validation: Loss: 0.4612, Accuracy: 80.0866%, Time: 1129.2120s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 8/30
# Epoch: 008, Training: Loss: 0.5194, Accuracy: 81.0606%,
# 		Validation: Loss: 0.5194, Accuracy: 76.6234%, Time: 1122.2330s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 9/30
# Epoch: 009, Training: Loss: 0.4500, Accuracy: 83.0628%,
# 		Validation: Loss: 0.4500, Accuracy: 81.8182%, Time: 1129.9270s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 10/30
# Epoch: 010, Training: Loss: 0.4869, Accuracy: 82.5758%,
# 		Validation: Loss: 0.4869, Accuracy: 81.8182%, Time: 1129.9300s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 11/30
# Epoch: 011, Training: Loss: 0.4606, Accuracy: 83.3874%,
# 		Validation: Loss: 0.4606, Accuracy: 80.5195%, Time: 1133.6460s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 12/30
# Epoch: 012, Training: Loss: 0.4701, Accuracy: 84.4156%,
# 		Validation: Loss: 0.4701, Accuracy: 81.8182%, Time: 1123.3320s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 13/30
# Epoch: 013, Training: Loss: 0.4447, Accuracy: 84.1450%,
# 		Validation: Loss: 0.4447, Accuracy: 81.8182%, Time: 1126.8080s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 14/30
# Epoch: 014, Training: Loss: 0.4316, Accuracy: 83.8745%,
# 		Validation: Loss: 0.4316, Accuracy: 81.8182%, Time: 1125.9240s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 15/30
# Epoch: 015, Training: Loss: 0.4658, Accuracy: 85.0108%,
# 		Validation: Loss: 0.4658, Accuracy: 78.7879%, Time: 1128.7260s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 16/30
# Epoch: 016, Training: Loss: 0.4471, Accuracy: 84.3615%,
# 		Validation: Loss: 0.4471, Accuracy: 80.9524%, Time: 1124.0940s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 17/30
# Epoch: 017, Training: Loss: 0.5293, Accuracy: 81.7641%,
# 		Validation: Loss: 0.5293, Accuracy: 80.5195%, Time: 1122.6410s
# Best Accuracy for validation : 0.8225 at epoch 004
# Epoch: 18/30
# Epoch: 018, Training: Loss: 0.4702, Accuracy: 84.6320%,
# 		Validation: Loss: 0.4702, Accuracy: 83.9827%, Time: 1132.6890s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 19/30
# Epoch: 019, Training: Loss: 0.4692, Accuracy: 85.7684%,
# 		Validation: Loss: 0.4692, Accuracy: 80.0866%, Time: 1129.4090s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 20/30
# Epoch: 020, Training: Loss: 0.4573, Accuracy: 86.4719%,
# 		Validation: Loss: 0.4573, Accuracy: 82.2511%, Time: 1306.1658s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 21/30
# Epoch: 021, Training: Loss: 0.4527, Accuracy: 86.2013%,
# 		Validation: Loss: 0.4527, Accuracy: 83.1169%, Time: 1279.7281s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 22/30
# Epoch: 022, Training: Loss: 0.4621, Accuracy: 86.6342%,
# 		Validation: Loss: 0.4621, Accuracy: 81.8182%, Time: 1160.7818s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 23/30
# Epoch: 023, Training: Loss: 0.4530, Accuracy: 84.5779%,
# 		Validation: Loss: 0.4530, Accuracy: 80.9524%, Time: 1144.2040s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 24/30
# Epoch: 024, Training: Loss: 0.4367, Accuracy: 83.2251%,
# 		Validation: Loss: 0.4367, Accuracy: 80.5195%, Time: 1141.2760s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 25/30
# Epoch: 025, Training: Loss: 0.4889, Accuracy: 84.4156%,
# 		Validation: Loss: 0.4889, Accuracy: 80.0866%, Time: 1137.4075s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 26/30
# Epoch: 026, Training: Loss: 0.5058, Accuracy: 86.7424%,
# 		Validation: Loss: 0.5058, Accuracy: 77.0563%, Time: 1139.5950s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 27/30
# Epoch: 027, Training: Loss: 0.4755, Accuracy: 86.0931%,
# 		Validation: Loss: 0.4755, Accuracy: 78.7879%, Time: 1142.4440s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 28/30
# Epoch: 028, Training: Loss: 0.4632, Accuracy: 86.1472%,
# 		Validation: Loss: 0.4632, Accuracy: 81.8182%, Time: 1139.1640s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 29/30
# Epoch: 029, Training: Loss: 0.4618, Accuracy: 86.5260%,
# 		Validation: Loss: 0.4618, Accuracy: 83.9827%, Time: 1141.1830s
# Best Accuracy for validation : 0.8398 at epoch 018
# Epoch: 30/30
# Epoch: 030, Training: Loss: 0.4624, Accuracy: 86.1472%,
# 		Validation: Loss: 0.4624, Accuracy: 82.2511%, Time: 1139.7202s
# Best Accuracy for validation : 0.8398 at epoch 018
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-007c5d5036bc> in <module>
#       1 num_epochs = 30
#       2 trained_model, history = train_and_valid(resnet50, loss_func, optimizer, num_epochs)
# ----> 3 torch.save(history, 'models/'+dataset+'_history.pt')
#       4
#       5 history = np.array(history)
#
# NameError: name 'dataset' is not defined

# %%
torch.save(history, 'F:\DataSets/modles/'+'_history.pt')

history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
plt.savefig('_loss_curve.png')
plt.show()
 
plt.plot(history[:, 2:4])
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
plt.savefig('_accuracy_curve.png')
plt.show()
