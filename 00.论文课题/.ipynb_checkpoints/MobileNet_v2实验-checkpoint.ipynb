# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
import numpy as np
from torchvision import datasets, models, transforms
import os
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
from torch.utils.data import Dataset
from torch.autograd import Variable
import time

# %%
data_dir = 'F:\DataSets/EmotionImages/TargetData'

data_transform = {x: transforms.Compose([transforms.Resize([256, 256]),  # 设置尺寸
                                        transforms.ToTensor(),  # 转为Tensor
                                        transforms.Normalize([0.485, 0.456, 0.406],
                                                             [0.229, 0.224, 0.225])])  # 标准化
                  for x in {"train", "valid"}}  # {"train":"训练集数据格式","valid":"测试集数据格式"}

image_datasets = {x: datasets.ImageFolder(root=os.path.join(data_dir, x),  # 载入数据
                                         transform = data_transform[x])
                  for x in {"train", "valid"}}  # {"train":"训练集","valid":"测试集"}

dataloader = {x: torch.utils.data.DataLoader(dataset=image_datasets[x],
                                            batch_size=16,
                                            shuffle=True)
              for x in {"train", "valid"}}  # {包装16个为一个批次"train":"训练集数据载入","valid":"测试集数据载入"}

# %%
train_data = dataloader["train"]
valid_data = dataloader["valid"]

train_data_size = len(image_datasets["train"])
valid_data_size = len(image_datasets["valid"])

print(train_data_size)
print(valid_data_size)
# Out:
# 1848
# 231

# %%
my_model = models.googlenet(pretrained=True)  # 使用VGG16 网络预训练好的模型

# %%
for param in my_model.parameters():
    param.requires_grad = True

# %%
fc_inputs = my_model.fc.in_features
my_model.fc = nn.Sequential(
    nn.Linear(fc_inputs, 256),
    nn.ReLU(),
    nn.Dropout(0.4),
    nn.Linear(256, 3),
    nn.LogSoftmax(dim=1)
)

# %%
loss_func = nn.CrossEntropyLoss()
optimizer = optim.Adam(my_model.parameters())

# %%
def train_and_valid(model, loss_function, optimizer, epochs=25):
    device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
    history = []
    best_acc = 0.0
    best_epoch = 0
 
    for epoch in range(epochs):
        epoch_start = time.time()
        print("Epoch: {}/{}".format(epoch+1, epochs))
 
        model.train()
 
        train_loss = 0.0
        train_acc = 0.0
        valid_loss = 0.0
        valid_acc = 0.0
 
        for i, (inputs, labels) in enumerate(train_data):
            inputs = inputs.to(device)
            labels = labels.to(device)
 
            #因为这里梯度是累加的，所以每次记得清零
            optimizer.zero_grad()
 
            outputs = model(inputs)
 
            loss = loss_function(outputs, labels)
 
            loss.backward()
 
            optimizer.step()
 
            train_loss += loss.item() * inputs.size(0)
 
            ret, predictions = torch.max(outputs.data, 1)
            correct_counts = predictions.eq(labels.data.view_as(predictions))
 
            acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
            train_acc += acc.item() * inputs.size(0)
 
        with torch.no_grad():
            model.eval()
 
            for j, (inputs, labels) in enumerate(valid_data):
                inputs = inputs.to(device)
                labels = labels.to(device)
 
                outputs = model(inputs)
 
                loss = loss_function(outputs, labels)
 
                valid_loss += loss.item() * inputs.size(0)
 
                ret, predictions = torch.max(outputs.data, 1)
                correct_counts = predictions.eq(labels.data.view_as(predictions))
 
                acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
                valid_acc += acc.item() * inputs.size(0)
 
        avg_train_loss = train_loss/train_data_size
        avg_train_acc = train_acc/train_data_size
 
        avg_valid_loss = valid_loss/valid_data_size
        avg_valid_acc = valid_acc/valid_data_size
 
        history.append([avg_train_loss, avg_valid_loss, avg_train_acc, avg_valid_acc])
 
        if best_acc < avg_valid_acc:
            best_acc = avg_valid_acc
            best_epoch = epoch + 1
 
        epoch_end = time.time()
 
        print("Epoch: {:03d}, Training: Loss: {:.4f}, Accuracy: {:.4f}%, \n\t\tValidation: Loss: {:.4f}, Accuracy: {:.4f}%, Time: {:.4f}s".format(
            epoch+1, avg_valid_loss, avg_train_acc*100, avg_valid_loss, avg_valid_acc*100, epoch_end-epoch_start
        ))
        print("Best Accuracy for validation : {:.4f} at epoch {:03d}".format(best_acc, best_epoch))
 
        torch.save(model, 'F:\DataSets/modles/'+'googleNet_'+str(epoch+1)+'.pt')
    return model, history

# %%
num_epochs = 20
trained_model, history = train_and_valid(my_model, loss_func, optimizer, num_epochs)
# Out:
# Epoch: 1/20
# Epoch: 001, Training: Loss: 0.5382, Accuracy: 73.5390%,
# 		Validation: Loss: 0.5382, Accuracy: 76.6234%, Time: 1246.1870s
# Best Accuracy for validation : 0.7662 at epoch 001
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type GoogLeNet. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BasicConv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Conv2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type BatchNorm2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type MaxPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Inception. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Sequential. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type AdaptiveAvgPool2d. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Dropout. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type Linear. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type ReLU. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# E:\Anaconda3\lib\site-packages\torch\serialization.py:292: UserWarning: Couldn't retrieve source code for container of type LogSoftmax. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "
# Epoch: 2/20
# Epoch: 002, Training: Loss: 0.3868, Accuracy: 79.3831%,
# 		Validation: Loss: 0.3868, Accuracy: 87.4459%, Time: 1275.9098s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 3/20
# Epoch: 003, Training: Loss: 0.5213, Accuracy: 82.8463%,
# 		Validation: Loss: 0.5213, Accuracy: 75.3247%, Time: 1257.6972s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 4/20
# Epoch: 004, Training: Loss: 0.3869, Accuracy: 82.9545%,
# 		Validation: Loss: 0.3869, Accuracy: 83.9827%, Time: 1259.3690s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 5/20
# Epoch: 005, Training: Loss: 0.4262, Accuracy: 85.9307%,
# 		Validation: Loss: 0.4262, Accuracy: 82.6840%, Time: 1259.4887s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 6/20
# Epoch: 006, Training: Loss: 0.5174, Accuracy: 87.3377%,
# 		Validation: Loss: 0.5174, Accuracy: 80.5195%, Time: 1264.1708s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 7/20
# Epoch: 007, Training: Loss: 0.3776, Accuracy: 85.4978%,
# 		Validation: Loss: 0.3776, Accuracy: 83.1169%, Time: 1259.1569s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 8/20
# Epoch: 008, Training: Loss: 1.1924, Accuracy: 88.0411%,
# 		Validation: Loss: 1.1924, Accuracy: 62.7706%, Time: 1264.3007s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 9/20
# Epoch: 009, Training: Loss: 0.5234, Accuracy: 86.2013%,
# 		Validation: Loss: 0.5234, Accuracy: 79.6537%, Time: 1265.2707s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 10/20
# Epoch: 010, Training: Loss: 0.4442, Accuracy: 90.6385%,
# 		Validation: Loss: 0.4442, Accuracy: 83.9827%, Time: 1261.1144s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 11/20
# Epoch: 011, Training: Loss: 0.8707, Accuracy: 91.2879%,
# 		Validation: Loss: 0.8707, Accuracy: 70.1299%, Time: 1263.7675s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 12/20
# Epoch: 012, Training: Loss: 0.4761, Accuracy: 91.1255%,
# 		Validation: Loss: 0.4761, Accuracy: 78.7879%, Time: 1262.3839s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 13/20
# Epoch: 013, Training: Loss: 0.5340, Accuracy: 92.3701%,
# 		Validation: Loss: 0.5340, Accuracy: 79.6537%, Time: 1258.7605s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 14/20
# Epoch: 014, Training: Loss: 0.5024, Accuracy: 93.0736%,
# 		Validation: Loss: 0.5024, Accuracy: 83.1169%, Time: 1304.8014s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 15/20
# Epoch: 015, Training: Loss: 0.5834, Accuracy: 93.5065%,
# 		Validation: Loss: 0.5834, Accuracy: 81.8182%, Time: 1301.7360s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 16/20
# Epoch: 016, Training: Loss: 0.6419, Accuracy: 94.2641%,
# 		Validation: Loss: 0.6419, Accuracy: 80.0866%, Time: 1286.9094s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 17/20
# Epoch: 017, Training: Loss: 0.6834, Accuracy: 95.2381%,
# 		Validation: Loss: 0.6834, Accuracy: 78.7879%, Time: 1265.4122s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 18/20
# Epoch: 018, Training: Loss: 0.7251, Accuracy: 95.2381%,
# 		Validation: Loss: 0.7251, Accuracy: 78.3550%, Time: 1265.1032s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 19/20
# Epoch: 019, Training: Loss: 0.5893, Accuracy: 95.8874%,
# 		Validation: Loss: 0.5893, Accuracy: 77.4892%, Time: 1262.3495s
# Best Accuracy for validation : 0.8745 at epoch 002
# Epoch: 20/20
# Epoch: 020, Training: Loss: 0.7933, Accuracy: 93.7771%,
# 		Validation: Loss: 0.7933, Accuracy: 79.2208%, Time: 1263.0306s
# Best Accuracy for validation : 0.8745 at epoch 002

# %%
torch.save(history, 'F:\DataSets/modles/'+'googlenet' + '_history.pt')

history = np.array(history)
plt.plot(history[:, 0:2])
plt.legend(['Tr Loss', 'Val Loss'])
plt.xlabel('Epoch Number')
plt.ylabel('Loss')
plt.ylim(0, 1)
# plt.savefig('resnet101_loss_curve.png')
plt.show()
 
plt.plot(history[:, 2:4]) 
plt.legend(['Tr Accuracy', 'Val Accuracy'])
plt.xlabel('Epoch Number')
plt.ylabel('Accuracy')
plt.ylim(0, 1)
# plt.savefig('resnet101_accuracy_curve.png')
plt.show()
